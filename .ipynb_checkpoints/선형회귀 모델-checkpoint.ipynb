# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '1.13.1'

# %%
x_data = [1,2,3]

# %%
y_data = [ 1,2,3]

# %%
W = tf.Variable(tf.random_uniform([1],-1.0, 1.0))

# %%
b = tf.Variable(tf.random_uniform([1], -1.0, 1.0))

# %%
X = tf.placeholder(tf.float32, name="X")

# %%
Y = tf.placeholder(tf.float32, name="Y")

# %%
hypothesis = W * X + b

# %%
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.1)

# %%
train_op = optimizer.minimize(cost)
# Out:
# WARNING:tensorflow:From /Users/dahlmoon/anaconda/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
with tf.Session() as sess :
    sess.run(tf.global_variables_initializer())
    for step in range(100) :
        _, cost_val = sess.run([train_op, cost], feed_dict={X: x_data, Y: y_data})
        print(step, cost_val, sess.run(W), sess.run(b))
        
    print(sess.run(hypothesis, feed_dict={X: 5}))
    print(sess.run(hypothesis, feed_dict={X: 2.5}))
# Out:
# 0 2.0623813 [1.2208891] [-0.3374234]
# 1 0.04341794 [1.1496953] [-0.35829437]
# 2 0.018408762 [1.1532974] [-0.3465136]
# 3 0.017260252 [1.1488253] [-0.33852986]
# 4 0.0164371 [1.1453336] [-0.330354]
# 5 0.015656272 [1.1418306] [-0.32241666]
# 6 0.014912598 [1.138422] [-0.31466556]
# 7 0.014204237 [1.1350944] [-0.30710125]
# 8 0.013529527 [1.1318468] [-0.29971877]
# 9 0.012886847 [1.1286774] [-0.29251373]
# 10 0.012274724 [1.125584] [-0.28548193]
# 11 0.011691666 [1.122565] [-0.27861914]
# 12 0.0111363195 [1.1196187] [-0.27192134]
# 13 0.010607325 [1.1167431] [-0.26538453]
# 14 0.010103479 [1.1139367] [-0.25900486]
# 15 0.009623546 [1.1111977] [-0.25277856]
# 16 0.00916642 [1.1085246] [-0.24670194]
# 17 0.00873101 [1.1059158] [-0.24077137]
# 18 0.008316284 [1.1033696] [-0.23498341]
# 19 0.007921247 [1.1008847] [-0.22933455]
# 20 0.0075449827 [1.0984595] [-0.2238215]
# 21 0.007186599 [1.0960926] [-0.21844101]
# 22 0.0068452195 [1.0937825] [-0.21318983]
# 23 0.006520077 [1.091528] [-0.20806488]
# 24 0.006210374 [1.0893278] [-0.20306315]
# 25 0.00591536 [1.0871805] [-0.19818163]
# 26 0.005634377 [1.0850847] [-0.19341749]
# 27 0.005366742 [1.0830393] [-0.18876785]
# 28 0.0051118173 [1.0810431] [-0.18422998]
# 29 0.0048689935 [1.0790949] [-0.17980123]
# 30 0.0046377224 [1.0771935] [-0.17547894]
# 31 0.0044174273 [1.0753378] [-0.17126055]
# 32 0.004207589 [1.0735267] [-0.16714354]
# 33 0.004007725 [1.0717592] [-0.16312551]
# 34 0.003817361 [1.0700341] [-0.1592041]
# 35 0.0036360426 [1.0683506] [-0.15537694]
# 36 0.0034633179 [1.0667075] [-0.15164179]
# 37 0.0032988042 [1.0651039] [-0.14799641]
# 38 0.0031421098 [1.0635389] [-0.14443867]
# 39 0.0029928554 [1.0620115] [-0.14096649]
# 40 0.0028507009 [1.0605206] [-0.13757779]
# 41 0.0027152877 [1.0590658] [-0.13427049]
# 42 0.002586311 [1.0576459] [-0.13104273]
# 43 0.0024634616 [1.0562601] [-0.12789257]
# 44 0.0023464442 [1.0549077] [-0.1248181]
# 45 0.002234981 [1.0535878] [-0.12181754]
# 46 0.002128817 [1.0522996] [-0.11888914]
# 47 0.0020277055 [1.0510423] [-0.11603117]
# 48 0.0019313846 [1.0498153] [-0.11324187]
# 49 0.0018396443 [1.0486177] [-0.11051962]
# 50 0.0017522558 [1.0474491] [-0.10786277]
# 51 0.0016690259 [1.0463084] [-0.10526987]
# 52 0.0015897414 [1.0451952] [-0.10273924]
# 53 0.0015142309 [1.0441087] [-0.10026949]
# 54 0.0014423007 [1.0430484] [-0.09785908]
# 55 0.0013737935 [1.0420135] [-0.09550661]
# 56 0.0013085346 [1.0410036] [-0.09321068]
# 57 0.0012463793 [1.0400178] [-0.09096997]
# 58 0.0011871756 [1.0390558] [-0.08878312]
# 59 0.001130788 [1.0381169] [-0.08664882]
# 60 0.0010770696 [1.0372007] [-0.08456583]
# 61 0.0010259093 [1.0363064] [-0.08253293]
# 62 0.0009771795 [1.0354335] [-0.0805489]
# 63 0.00093075895 [1.0345818] [-0.07861253]
# 64 0.00088655035 [1.0337504] [-0.07672274]
# 65 0.00084443734 [1.0329391] [-0.07487836]
# 66 0.0008043251 [1.0321473] [-0.07307832]
# 67 0.00076611666 [1.0313745] [-0.07132156]
# 68 0.00072972896 [1.0306202] [-0.06960703]
# 69 0.0006950666 [1.0298841] [-0.06793372]
# 70 0.0006620477 [1.0291657] [-0.06630062]
# 71 0.000630601 [1.0284647] [-0.06470679]
# 72 0.0006006456 [1.0277804] [-0.06315129]
# 73 0.0005721135 [1.0271126] [-0.06163319]
# 74 0.00054494274 [1.0264608] [-0.0601516]
# 75 0.0005190565 [1.0258247] [-0.0587056]
# 76 0.0004944022 [1.0252038] [-0.05729436]
# 77 0.0004709169 [1.024598] [-0.05591702]
# 78 0.00044854512 [1.0240067] [-0.05457281]
# 79 0.0004272392 [1.0234296] [-0.05326093]
# 80 0.00040694498 [1.0228664] [-0.05198058]
# 81 0.00038761916 [1.0223166] [-0.05073103]
# 82 0.0003692057 [1.0217801] [-0.04951146]
# 83 0.00035166708 [1.0212566] [-0.04832124]
# 84 0.00033496317 [1.0207456] [-0.04715962]
# 85 0.00031904946 [1.020247] [-0.04602594]
# 86 0.00030389582 [1.0197603] [-0.04491954]
# 87 0.00028946289 [1.0192851] [-0.04383974]
# 88 0.00027571074 [1.0188216] [-0.04278582]
# 89 0.00026261355 [1.0183692] [-0.04175728]
# 90 0.00025014015 [1.0179275] [-0.0407535]
# 91 0.00023825669 [1.0174966] [-0.0397738]
# 92 0.00022694263 [1.0170759] [-0.03881768]
# 93 0.00021616086 [1.0166655] [-0.0378845]
# 94 0.00020589323 [1.0162648] [-0.03697379]
# 95 0.00019611286 [1.0158739] [-0.03608494]
# 96 0.00018679832 [1.0154922] [-0.03521752]
# 97 0.00017792483 [1.0151198] [-0.0343709]
# 98 0.00016947318 [1.0147563] [-0.03354464]
# 99 0.00016142489 [1.0144016] [-0.03273825]
# [5.0392694]
# [2.5032656]
