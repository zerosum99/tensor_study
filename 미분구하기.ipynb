# %%
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
 
def numerical_differentiation(f, x):    # 수치미분
    delta_x = 1e-7    # 0.0000001
    # return (f(x+delta_x) - f(x)) / delta_x            # 전진 차분
    return (f(x+delta_x) - f(x-delta_x)) / (delta_x*2)  # 중앙 차분
    # return (f(x) - f(x-delta_x)) / delta_x            # 후진 차분
 
 
def f1(x):
    return x**2
 
def f2(x):
    return x**3 + x**2
 
x = np.arange(0,10,0.01)
 
plt.plot(x, f1(x), label="f1(x)")
plt.plot(x, numerical_differentiation(f1,x), label="f1(x)_derivative")

plt.legend()

# %%
plt.plot(x, f2(x), label="f2(x)")
plt.plot(x, numerical_differentiation(f2,x), label="f2(x)_derivative")
plt.legend()

# %%
delta = 1e-7

# %%
plt.plot(x, f1(x), label="f1(x)")

# %%
help(np.gradient)
# Out:
# Help on function gradient in module numpy:
#
# gradient(f, *varargs, **kwargs)
#     Return the gradient of an N-dimensional array.
#
#     The gradient is computed using second order accurate central differences
#     in the interior points and either first or second order accurate one-sides
#     (forward or backwards) differences at the boundaries.
#     The returned gradient hence has the same shape as the input array.
#
#     Parameters
#     ----------
#     f : array_like
#         An N-dimensional array containing samples of a scalar function.
#     varargs : list of scalar or array, optional
#         Spacing between f values. Default unitary spacing for all dimensions.
#         Spacing can be specified using:
#
#         1. single scalar to specify a sample distance for all dimensions.
#         2. N scalars to specify a constant sample distance for each dimension.
#            i.e. `dx`, `dy`, `dz`, ...
# ...

# %%
f = x **2

# %%
## 에지오더 : edge_order

# %%
plt.plot(x, f1(x), label="f1(x)")

# %%
np.gradient(f,edge_order=1 )
# Out:
# array([1.000e-04, 2.000e-04, 4.000e-04, 6.000e-04, 8.000e-04, 1.000e-03,
#        1.200e-03, 1.400e-03, 1.600e-03, 1.800e-03, 2.000e-03, 2.200e-03,
#        2.400e-03, 2.600e-03, 2.800e-03, 3.000e-03, 3.200e-03, 3.400e-03,
#        3.600e-03, 3.800e-03, 4.000e-03, 4.200e-03, 4.400e-03, 4.600e-03,
#        4.800e-03, 5.000e-03, 5.200e-03, 5.400e-03, 5.600e-03, 5.800e-03,
#        6.000e-03, 6.200e-03, 6.400e-03, 6.600e-03, 6.800e-03, 7.000e-03,
#        7.200e-03, 7.400e-03, 7.600e-03, 7.800e-03, 8.000e-03, 8.200e-03,
#        8.400e-03, 8.600e-03, 8.800e-03, 9.000e-03, 9.200e-03, 9.400e-03,
#        9.600e-03, 9.800e-03, 1.000e-02, 1.020e-02, 1.040e-02, 1.060e-02,
#        1.080e-02, 1.100e-02, 1.120e-02, 1.140e-02, 1.160e-02, 1.180e-02,
#        1.200e-02, 1.220e-02, 1.240e-02, 1.260e-02, 1.280e-02, 1.300e-02,
#        1.320e-02, 1.340e-02, 1.360e-02, 1.380e-02, 1.400e-02, 1.420e-02,
#        1.440e-02, 1.460e-02, 1.480e-02, 1.500e-02, 1.520e-02, 1.540e-02,
# ...

# %%
plt.plot(x, np.gradient(f,edge_order=1 ), label="f1(x)")

# %%
plt.plot(x, f1(x), label="f1(x)")
plt.plot(x, np.gradient(f,1 ), label="f1(x)_derivative")
plt.ylim(-0.001, 0.3)
plt.legend()

# %%
np.gradient(f,edge_order=2 )
# Out:
# array([0.    , 0.0002, 0.0004, 0.0006, 0.0008, 0.001 , 0.0012, 0.0014,
#        0.0016, 0.0018, 0.002 , 0.0022, 0.0024, 0.0026, 0.0028, 0.003 ,
#        0.0032, 0.0034, 0.0036, 0.0038, 0.004 , 0.0042, 0.0044, 0.0046,
#        0.0048, 0.005 , 0.0052, 0.0054, 0.0056, 0.0058, 0.006 , 0.0062,
#        0.0064, 0.0066, 0.0068, 0.007 , 0.0072, 0.0074, 0.0076, 0.0078,
#        0.008 , 0.0082, 0.0084, 0.0086, 0.0088, 0.009 , 0.0092, 0.0094,
#        0.0096, 0.0098, 0.01  , 0.0102, 0.0104, 0.0106, 0.0108, 0.011 ,
#        0.0112, 0.0114, 0.0116, 0.0118, 0.012 , 0.0122, 0.0124, 0.0126,
#        0.0128, 0.013 , 0.0132, 0.0134, 0.0136, 0.0138, 0.014 , 0.0142,
#        0.0144, 0.0146, 0.0148, 0.015 , 0.0152, 0.0154, 0.0156, 0.0158,
#        0.016 , 0.0162, 0.0164, 0.0166, 0.0168, 0.017 , 0.0172, 0.0174,
#        0.0176, 0.0178, 0.018 , 0.0182, 0.0184, 0.0186, 0.0188, 0.019 ,
#        0.0192, 0.0194, 0.0196, 0.0198, 0.02  , 0.0202, 0.0204, 0.0206,
# ...

# %%
plt.plot(x, np.gradient(f,edge_order=2 ), label="f1(x)")

# %%
plt.plot(x, f1(x), label="f1(x)")
plt.plot(x, np.gradient(f,2 ), label="f1(x)_derivative")
plt.ylim(-0.1, 0.21) 
plt.legend()

# %%
plt.plot(x, f1(x), label="f1(x)")
plt.plot(x, np.gradient(f ), label="f1(x)_derivative")
plt.ylim(-0.1, 0.21) 
plt.legend()

# %%
plt.plot(x, f1(x), label="f1(x)")
plt.plot(x, np.gradient(f ), label="f1(x)_derivative")
plt.ylim(-0.1, 0.21) 
plt.legend()

# %%
plt.plot(x, f1(x), label="f1(x)")
plt.plot(x, np.gradient(f, edge_order=1 ), label="f1(x)_derivative")
plt.ylim(-0.1, 0.21) 
plt.legend()

# %%
plt.plot(x, f1(x), label="f1(x)")
plt.plot(x, np.gradient(f, edge_order=2 ), label="f1(x)_derivative")
plt.ylim(-0.1, 0.21) 
plt.legend()

# %%
f_2 = x**3 + x**2

# %%
dx = 1/(1e7)

# %%
plt.plot(x, f1(x), label="f1(x)")
plt.plot(x, np.gradient(f_2,2 ), label="f1(x)_derivative")
 
plt.legend()

# %%
plt.plot(x, f1(x), label="f1(x)")
plt.plot(x, np.gradient(f_2, edge_order=2 ), label="f1(x)_derivative")
plt.ylim(-0.1, 0.21) 
plt.legend()

# %%
(f(x+delta_x) - f(x)) / delta_x            # 전진 차분

(2-1), {(2-1)+(4-2)}/2, {(4-2)+(10-4)}/2, {(10-4)+(13-10)}/2, {(13-10)+(20-13)}/2, (20-13)

# %%
g = np.array([ 1, 2, 4, 10, 13, 20])

# %%
np.gradient(g)
# Out:
# array([1. , 1.5, 4. , 4.5, 5. , 7. ])

# %%
x :int = 10
y : float = 10.0

# %%
__annotations__
# Out:
# {'x': int, 'y': float}

# %%
assert  isinstance(vars()['x'], __annotations__['x']) == True

# %%
y= 10

# %%
assert  isinstance(vars()['y'], __annotations__['y']) == True
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-50-5059343d51eb> in <module>
# ----> 1 assert  isinstance(vars()['y'], __annotations__['y']) == True
#
# AssertionError:

# %%
import math

# %%
# %%writefile aaa.py

x : int = 100
    
print(__annotations__)
# Out:
# Overwriting aaa.py

# %%
import aaa

print(aaa.__annotations__)
# Out:
# {'x': <class 'int'>}
