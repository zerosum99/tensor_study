# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '1.12.0'

# %%
import numpy as np

# %%
raw_data = np.random.normal(10,1,100)

# %%
raw_data
# Out:
# array([10.12657838, 12.04133608,  9.79210095, 10.49040521,  8.85742692,
#         8.96957783,  9.07531765,  9.68211275, 10.36402245,  7.20258073,
#        10.48416116,  8.81171983, 11.14682081, 10.91796377,  9.76637568,
#         7.69296615, 11.1019946 , 11.38435699,  9.52386952, 10.10396205,
#         8.33965595,  9.73187637, 10.83515144,  9.32222843, 10.32046638,
#        10.70709035,  9.73920681,  9.60134328,  9.510502  , 10.06446897,
#        12.06666612, 10.79097304,  8.67916984,  9.4693848 ,  9.02267806,
#         8.59734163,  8.65952273,  8.98764472, 10.19370632, 10.25163219,
#         9.91492309,  9.38014887, 10.41741977,  9.42922436, 10.45010665,
#        10.26442361, 10.90964417,  9.22966963, 10.39202699,  9.81487714,
#         8.78239564,  8.64446177, 10.32099661, 10.06780833,  8.39290254,
#        10.15939621, 10.19381178, 10.72929725, 10.25089401, 10.33275248,
#         8.09458693,  8.38769692,  9.80200485,  9.40147858, 10.33086793,
#         9.84942306,  9.44784577,  8.49878031, 10.47071266, 10.59973205,
#        11.52814619,  9.28886694, 10.65531206,  9.91014284,  9.70272451,
#         9.85194996, 10.5990857 , 11.12422791, 11.38473686,  7.94791905,
#         9.8326113 ,  8.9599046 , 10.54892309, 10.04539843,  9.3908642 ,
#        11.01617132, 11.86797707, 10.81415003,  9.5314248 , 11.03910212,
#         9.41777853,  9.14369138, 10.85626953, 11.56686726, 10.22150526,
#         9.95693031, 10.5913246 ,  9.9489322 , 11.5139292 ,  9.58219934])

# %%
alpha = tf.constant(0.05)

# %%
curr_value = tf.placeholder(tf.float32)

# %%
prev_avg = tf.Variable(0.)

# %%
update_avg = alpha * curr_value + (1 - alpha) * prev_avg

# %%
avg_hist = tf.summary.scalar("running_average", update_avg)

# %%
value_hist = tf.summary.scalar("incoming_values", curr_value)

# %%
merged = tf.summary.merge_all()

# %%
writer = tf.summary.FileWriter("./logs")

# %%
init = tf.global_variables_initializer()

# %%
with tf.Session() as sess :
    sess.run(init)
    for i in range(len(raw_data)) :
        summary_str, curr_avg = sess.run([merged, update_avg],
                                        feed_dict={curr_value: raw_data[i]})
        
        sess.run(tf.assign(prev_avg, curr_avg))
        print(raw_data[i], curr_avg)
        
        writer.add_summary(summary_str, i)
# Out:
# 10.126578380779721 0.50632894
# 12.041336075244224 1.0830793
# 9.792100953863287 1.5185304
# 10.49040521195413 1.9671241
# 8.857426922944443 2.3116393
# 8.96957783020477 2.6445363
# 9.075317653388879 2.9660752
# 9.682112750821801 3.301877
# 10.36402244649739 3.6549842
# 7.202580728869074 3.832364
# 10.48416115527134 4.164954
